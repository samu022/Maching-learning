# %%
import pandas as pd

# %%
melb_df = pd.read_csv('melb_data.csv')
melb_df = melb_df.iloc[:, 1:]
melb_df
# Out:
#              Suburb           Address  Rooms Type      Price Method  \
# 0        Abbotsford      85 Turner St      2    h  1480000.0      S
# 1        Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2        Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3        Abbotsford  40 Federation La      3    h   850000.0     PI
# 4        Abbotsford       55a Park St      4    h  1600000.0     VB
# ...             ...               ...    ...  ...        ...    ...
# 18391  Williamstown   8/2 Thompson St      2    t   622500.0     SP
# 18392  Williamstown      96 Verdon St      4    h  2500000.0     PI
# 18393     Yallambie      17 Amaroo Wy      4    h  1100000.0      S
# 18394    Yarraville        6 Agnes St      4    h  1285000.0     SP
# 18395    Yarraville     33 Freeman St      4    h  1050000.0     VB
#
#           SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 0          Biggin   3/12/2016       2.5    3067.0  ...       1.0  1.0
# 1          Biggin   4/02/2016       2.5    3067.0  ...       1.0  0.0
# 2          Biggin   4/03/2017       2.5    3067.0  ...       2.0  0.0
# 3          Biggin   4/03/2017       2.5    3067.0  ...       2.0  1.0
# 4          Nelson   4/06/2016       2.5    3067.0  ...       1.0  2.0
# ...           ...         ...       ...       ...  ...       ...  ...
# 18391        Greg  26/08/2017       6.8    3016.0  ...       2.0  1.0
# 18392     Sweeney  26/08/2017       6.8    3016.0  ...       1.0  5.0
# 18393  Buckingham  26/08/2017      12.7    3085.0  ...       3.0  2.0
# 18394     Village  26/08/2017       6.3    3013.0  ...       1.0  1.0
# 18395     Village  26/08/2017       6.3    3013.0  ...       2.0  2.0
#
#        Landsize  BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 0         202.0           NaN        NaN        Yarra -37.79960   144.99840
# 1         156.0          79.0     1900.0        Yarra -37.80790   144.99340
# 2         134.0         150.0     1900.0        Yarra -37.80930   144.99440
# 3          94.0           NaN        NaN        Yarra -37.79690   144.99690
# 4         120.0         142.0     2014.0        Yarra -37.80720   144.99410
# ...         ...           ...        ...          ...       ...         ...
# 18391       NaN          89.0     2010.0          NaN -37.86393   144.90484
# 18392     866.0         157.0     1920.0          NaN -37.85908   144.89299
# 18393       NaN           NaN        NaN          NaN -37.72006   145.10547
# 18394     362.0         112.0     1920.0          NaN -37.81188   144.88449
# 18395       NaN         139.0     1950.0          NaN -37.81829   144.87404
#
#                   Regionname Propertycount
# 0      Northern Metropolitan        4019.0
# 1      Northern Metropolitan        4019.0
# 2      Northern Metropolitan        4019.0
# 3      Northern Metropolitan        4019.0
# 4      Northern Metropolitan        4019.0
# ...                      ...           ...
# 18391   Western Metropolitan        6380.0
# 18392   Western Metropolitan        6380.0
# 18393  Northern Metropolitan        1369.0
# 18394   Western Metropolitan        6543.0
# 18395   Western Metropolitan        6543.0
#
# [18396 rows x 21 columns]

# %%
melb_df.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  18396.000000  1.839600e+04  18395.000000  18395.000000  14927.000000
# mean       2.935040  1.056697e+06     10.389986   3107.140147      2.913043
# std        0.958202  6.419217e+05      6.009050     95.000995      0.964641
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.330000e+05      6.300000   3046.000000      2.000000
# 50%        3.000000  8.800000e+05      9.700000   3085.000000      3.000000
# 75%        3.000000  1.302000e+06     13.300000   3149.000000      3.000000
# max       12.000000  9.000000e+06     48.100000   3978.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  14925.000000  14820.000000   13603.000000   7762.000000  8958.000000
# mean       1.538492      1.615520     558.116371    151.220219  1965.879996
# std        0.689311      0.955916    3987.326586    519.188596    37.013261
# min        0.000000      0.000000       0.000000      0.000000  1196.000000
# 25%        1.000000      1.000000     176.500000     93.000000  1950.000000
# 50%        1.000000      2.000000     440.000000    126.000000  1970.000000
# 75%        2.000000      2.000000     651.000000    174.000000  2000.000000
# max        8.000000     10.000000  433014.000000  44515.000000  2018.000000
#
#           Lattitude    Longtitude  Propertycount
# count  15064.000000  15064.000000   18395.000000
# mean     -37.809849    144.996338    7517.975265
# std        0.081152      0.106375    4488.416599
# min      -38.182550    144.431810     249.000000
# 25%      -37.858100    144.931193    4294.000000
# 50%      -37.803625    145.000920    6567.000000
# 75%      -37.756270    145.060000   10331.000000
# max      -37.408530    145.526350   21650.000000

# %% [markdown]
# # Limpieza de datos

# %%
melb_df = melb_df.dropna(axis=0)
melb_df
# Out:
#              Suburb          Address  Rooms Type      Price Method  \
# 1        Abbotsford  25 Bloomburg St      2    h  1035000.0      S
# 2        Abbotsford     5 Charles St      3    h  1465000.0     SP
# 4        Abbotsford      55a Park St      4    h  1600000.0     VB
# 6        Abbotsford     124 Yarra St      3    h  1876000.0      S
# 7        Abbotsford    98 Charles St      2    h  1636000.0      S
# ...             ...              ...    ...  ...        ...    ...
# 15388    Whittlesea    30 Sherwin St      3    h   601000.0      S
# 15389  Williamstown      75 Cecil St      3    h  1050000.0     VB
# 15390  Williamstown    2/29 Dover Rd      1    u   385000.0     SP
# 15392       Windsor  201/152 Peel St      2    u   560000.0     PI
# 15395    Yarraville  54 Pentland Pde      6    h  2450000.0     VB
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 1             Biggin   4/02/2016       2.5    3067.0  ...       1.0  0.0
# 2             Biggin   4/03/2017       2.5    3067.0  ...       2.0  0.0
# 4             Nelson   4/06/2016       2.5    3067.0  ...       1.0  2.0
# 6             Nelson   7/05/2016       2.5    3067.0  ...       2.0  0.0
# 7             Nelson   8/10/2016       2.5    3067.0  ...       1.0  2.0
# ...              ...         ...       ...       ...  ...       ...  ...
# 15388            Ray  29/07/2017      35.5    3757.0  ...       2.0  1.0
# 15389       Williams  29/07/2017       6.8    3016.0  ...       1.0  0.0
# 15390       Williams  29/07/2017       6.8    3016.0  ...       1.0  1.0
# 15392  hockingstuart  29/07/2017       4.6    3181.0  ...       1.0  1.0
# 15395        Village  29/07/2017       6.3    3013.0  ...       3.0  2.0
#
#        Landsize  BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 1         156.0         79.00     1900.0        Yarra -37.80790   144.99340
# 2         134.0        150.00     1900.0        Yarra -37.80930   144.99440
# 4         120.0        142.00     2014.0        Yarra -37.80720   144.99410
# 6         245.0        210.00     1910.0        Yarra -37.80240   144.99930
# 7         256.0        107.00     1890.0        Yarra -37.80600   144.99540
# ...         ...           ...        ...          ...       ...         ...
# 15388     972.0        149.00     1996.0   Whittlesea -37.51232   145.13282
# 15389     179.0        115.00     1890.0  Hobsons Bay -37.86558   144.90474
# 15390       0.0         35.64     1967.0  Hobsons Bay -37.85588   144.89936
# 15392       0.0         61.60     2012.0  Stonnington -37.85581   144.99025
# 15395    1087.0        388.50     1920.0  Maribyrnong -37.81038   144.89389
#
#                   Regionname Propertycount
# 1      Northern Metropolitan        4019.0
# 2      Northern Metropolitan        4019.0
# 4      Northern Metropolitan        4019.0
# 6      Northern Metropolitan        4019.0
# 7      Northern Metropolitan        4019.0
# ...                      ...           ...
# 15388      Northern Victoria        2170.0
# 15389   Western Metropolitan        6380.0
# 15390   Western Metropolitan        6380.0
# 15392  Southern Metropolitan        4380.0
# 15395   Western Metropolitan        6543.0
#
# [6196 rows x 21 columns]

# %% [markdown]
# # Maching learning

# %%
y = melb_df['Price']
X = melb_df[['Rooms', 'Bathroom', 'Landsize', 'Lattitude', 'Longtitude']]

# %%
from sklearn.tree import DecisionTreeRegressor
melbourne_model = DecisionTreeRegressor()
melbourne_model.fit(X, y)
# Out:
# DecisionTreeRegressor()

# %%
print("Predicciones para las 5 primeras caas: ")
print(X.head())
print("El precio real es")
print(y.head())
print("Las predicciones son")
print(melbourne_model.predict(X.head()))
# Out:
# Predicciones para las 5 primeras caas:
#    Rooms  Bathroom  Landsize  Lattitude  Longtitude
# 1      2       1.0     156.0   -37.8079    144.9934
# 2      3       2.0     134.0   -37.8093    144.9944
# 4      4       1.0     120.0   -37.8072    144.9941
# 6      3       2.0     245.0   -37.8024    144.9993
# 7      2       1.0     256.0   -37.8060    144.9954
# El precio real es
# 1    1035000.0
# 2    1465000.0
# 4    1600000.0
# 6    1876000.0
# 7    1636000.0
# Name: Price, dtype: float64
# Las predicciones son
# [1035000. 1465000. 1600000. 1876000. 1636000.]

# %% [markdown]
# # MAE (Mean absolute error)

# %%
from sklearn.metrics import mean_absolute_error

predicted_home_prices = melbourne_model.predict(X)
mean_absolute_error(y, predicted_home_prices)
# Out:
# 1115.7467183128902

# %% [markdown]
# # Validación

# %%
from sklearn.model_selection import train_test_split
train_X, val_X, train_y, val_y = train_test_split(X,y)
melbourne_model = DecisionTreeRegressor()
melbourne_model.fit(train_X, train_y)

val_predictions = melbourne_model.predict(val_X)
print(mean_absolute_error(val_y, val_predictions))
# Out:
# 262112.8676565526

# %%
def get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y):
    model=DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes)
    model.fit(train_X, train_y)
    preds_val = model.predict(val_X)
    mae = mean_absolute_error(val_y, preds_val)
    return(mae)

# %%
for max_leaf_nodes in [5,50,500,5000]:
    my_mae = get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y)
    print("Max leaf nodes: %d \t\t Mean Absolute Error: %d" %(max_leaf_nodes, my_mae))
# Out:
# Max leaf nodes: 5 		 Mean Absolute Error: 383837
# Max leaf nodes: 50 		 Mean Absolute Error: 264844
# Max leaf nodes: 500 		 Mean Absolute Error: 245052
# Max leaf nodes: 5000 		 Mean Absolute Error: 263266

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
forest_model = RandomForestRegressor()
forest_model.fit(train_X, train_y)
melb_preds = forest_model.predict(val_X)
print(mean_absolute_error(val_y, melb_preds))
# Out:
# 196497.0206800086
